# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.cluster import DBSCAN

# %%
X,y=make_moons(n_samples=1000,noise=0.09)

# %%
X
# Out:
# array([[ 1.89910087, -0.17467906],
#        [ 1.86352106, -0.07549987],
#        [ 2.08394573,  0.4140515 ],
#        ...,
#        [ 0.14796617,  0.45358675],
#        [-0.78318654,  0.55242958],
#        [ 0.13380256,  0.23213731]])

# %%
plt.scatter(X[:,0],X[:,1],c=y)

# %%
##feature scaling
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_scacled=scaler.fit_transform(X)

# %%
X_scacled
# Out:
# array([[ 1.60267633, -0.83636955],
#        [ 1.56183584, -0.63889578],
#        [ 1.81485158,  0.33584051],
#        ...,
#        [-0.40737389,  0.41455838],
#        [-1.47620299,  0.61136243],
#        [-0.42363169, -0.02636533]])

# %%
dbscan=DBSCAN(eps=0.3)

# %%
dbscan.fit(X_scacled)
# Out:
# DBSCAN(eps=0.3)

# %%
label=dbscan.labels_

# %%
plt.scatter(X[:,0],X[:,1],c=label)
